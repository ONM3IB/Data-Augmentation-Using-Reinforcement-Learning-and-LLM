# %% [markdown]
# # Tune GPT2 to generate positive tweets

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %pip install transformers trl wandb datasets
# Out:
# Requirement already satisfied: transformers in /usr/local/lib/python3.10/dist-packages (4.35.2)
# Collecting trl
#   Downloading trl-0.7.7-py3-none-any.whl (139 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.1/139.1 kB 3.1 MB/s eta 0:00:00
# Collecting wandb
#   Downloading wandb-0.16.1-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 40.6 MB/s eta 0:00:00
# Collecting datasets
#   Downloading datasets-2.16.1-py3-none-any.whl (507 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 507.1/507.1 kB 47.4 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from transformers) (3.13.1)
# Requirement already satisfied: huggingface-hub<1.0,>=0.16.4 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.19.4)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from transformers) (23.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (6.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.10/dist-packages (from transformers) (2023.6.3)
# Requirement already satisfied: requests in /usr/local/lib/python3.10/dist-packages (from transformers) (2.31.0)
# Requirement already satisfied: tokenizers<0.19,>=0.14 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.15.0)
# Requirement already satisfied: safetensors>=0.3.1 in /usr/local/lib/python3.10/dist-packages (from transformers) (0.4.1)
# Requirement already satisfied: tqdm>=4.27 in /usr/local/lib/python3.10/dist-packages (from transformers) (4.66.1)
# Requirement already satisfied: torch>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from trl) (2.1.0+cu121)
# Collecting accelerate (from trl)
#   Downloading accelerate-0.25.0-py3-none-any.whl (265 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 265.7/265.7 kB 31.3 MB/s eta 0:00:00
# Collecting tyro>=0.5.11 (from trl)
#   Downloading tyro-0.6.3-py3-none-any.whl (78 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 78.9/78.9 kB 11.9 MB/s eta 0:00:00
# Requirement already satisfied: Click!=8.0.0,>=7.1 in /usr/local/lib/python3.10/dist-packages (from wandb) (8.1.7)
# Collecting GitPython!=3.1.29,>=1.0.0 (from wandb)
#   Downloading GitPython-3.1.40-py3-none-any.whl (190 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 190.6/190.6 kB 24.9 MB/s eta 0:00:00
# Requirement already satisfied: psutil>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (5.9.5)
# Collecting sentry-sdk>=1.0.0 (from wandb)
#   Downloading sentry_sdk-1.39.1-py2.py3-none-any.whl (254 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 254.1/254.1 kB 30.7 MB/s eta 0:00:00
# Collecting docker-pycreds>=0.4.0 (from wandb)
#   Downloading docker_pycreds-0.4.0-py2.py3-none-any.whl (9.0 kB)
# Collecting setproctitle (from wandb)
#   Downloading setproctitle-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (30 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.10/dist-packages (from wandb) (67.7.2)
# Requirement already satisfied: appdirs>=1.4.3 in /usr/local/lib/python3.10/dist-packages (from wandb) (1.4.4)
# Requirement already satisfied: protobuf!=4.21.0,<5,>=3.19.0 in /usr/local/lib/python3.10/dist-packages (from wandb) (3.20.3)
# Requirement already satisfied: pyarrow>=8.0.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (10.0.1)
# Collecting pyarrow-hotfix (from datasets)
#   Downloading pyarrow_hotfix-0.6-py3-none-any.whl (7.9 kB)
# Collecting dill<0.3.8,>=0.3.0 (from datasets)
#   Downloading dill-0.3.7-py3-none-any.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 16.0 MB/s eta 0:00:00
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (from datasets) (1.5.3)
# Requirement already satisfied: xxhash in /usr/local/lib/python3.10/dist-packages (from datasets) (3.4.1)
# Collecting multiprocess (from datasets)
#   Downloading multiprocess-0.70.15-py310-none-any.whl (134 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 134.8/134.8 kB 18.3 MB/s eta 0:00:00
# Requirement already satisfied: fsspec[http]<=2023.10.0,>=2023.1.0 in /usr/local/lib/python3.10/dist-packages (from datasets) (2023.6.0)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.10/dist-packages (from datasets) (3.9.1)
# Requirement already satisfied: six>=1.4.0 in /usr/local/lib/python3.10/dist-packages (from docker-pycreds>=0.4.0->wandb) (1.16.0)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (23.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.9.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.4.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->datasets) (4.0.3)
# Collecting gitdb<5,>=4.0.1 (from GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading gitdb-4.0.11-py3-none-any.whl (62 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.7/62.7 kB 8.9 MB/s eta 0:00:00
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.10/dist-packages (from huggingface-hub<1.0,>=0.16.4->transformers) (4.5.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests->transformers) (2023.11.17)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (1.12)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.2.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (3.1.2)
# Requirement already satisfied: triton==2.1.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.4.0->trl) (2.1.0)
# Collecting docstring-parser>=0.14.1 (from tyro>=0.5.11->trl)
#   Downloading docstring_parser-0.15-py3-none-any.whl (36 kB)
# Requirement already satisfied: rich>=11.1.0 in /usr/local/lib/python3.10/dist-packages (from tyro>=0.5.11->trl) (13.7.0)
# Collecting shtab>=1.5.6 (from tyro>=0.5.11->trl)
#   Downloading shtab-1.6.5-py3-none-any.whl (13 kB)
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas->datasets) (2023.3.post1)
# Collecting smmap<6,>=3.0.1 (from gitdb<5,>=4.0.1->GitPython!=3.1.29,>=1.0.0->wandb)
#   Downloading smmap-5.0.1-py3-none-any.whl (24 kB)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.10/dist-packages (from rich>=11.1.0->tyro>=0.5.11->trl) (2.16.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.4.0->trl) (2.1.3)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.4.0->trl) (1.3.0)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.10/dist-packages (from markdown-it-py>=2.2.0->rich>=11.1.0->tyro>=0.5.11->trl) (0.1.2)
# Installing collected packages: smmap, shtab, setproctitle, sentry-sdk, pyarrow-hotfix, docstring-parser, docker-pycreds, dill, multiprocess, gitdb, tyro, GitPython, accelerate, wandb, datasets, trl
# Successfully installed GitPython-3.1.40 accelerate-0.25.0 datasets-2.16.1 dill-0.3.7 docker-pycreds-0.4.0 docstring-parser-0.15 gitdb-4.0.11 multiprocess-0.70.15 pyarrow-hotfix-0.6 sentry-sdk-1.39.1 setproctitle-1.3.3 shtab-1.6.5 smmap-5.0.1 trl-0.7.7 tyro-0.6.3 wandb-0.16.1

# %%
import torch
from tqdm import tqdm
import pandas as pd

tqdm.pandas()

from transformers import pipeline, AutoTokenizer
from datasets import load_dataset

from trl import PPOTrainer, PPOConfig, AutoModelForCausalLMWithValueHead
from trl.core import LengthSampler

# %%
config = PPOConfig(
    model_name="redrussianarmy/gpt2-turkish-cased",
    learning_rate=1e-5,
    log_with="wandb",
)

sent_kwargs = {"return_all_scores": True, "function_to_apply": "none", "batch_size": 64}

# %%
import wandb

wandb.init()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# Tracking run with wandb version 0.16.1
# Run data is saved locally in <code>/content/wandb/run-20240101_102028-3bmmo6ku</code>
# Syncing run <strong><a href='https://wandb.ai/ytu-bitirme-projesi/uncategorized/runs/3bmmo6ku' target="_blank">glowing-lion-21</a></strong> to <a href='https://wandb.ai/ytu-bitirme-projesi/uncategorized' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ytu-bitirme-projesi/uncategorized' target="_blank">https://wandb.ai/ytu-bitirme-projesi/uncategorized</a>
#  View run at <a href='https://wandb.ai/ytu-bitirme-projesi/uncategorized/runs/3bmmo6ku' target="_blank">https://wandb.ai/ytu-bitirme-projesi/uncategorized/runs/3bmmo6ku</a>
# <button onClick="this.nextSibling.style.display='block';this.style.display='none';">Display W&B run</button><iframe src='https://wandb.ai/ytu-bitirme-projesi/uncategorized/runs/3bmmo6ku?jupyter=true' style='border:none;width:100%;height:420px;display:none;'></iframe>

# %%
def build_dataset(config, input_min_text_length=2, input_max_text_length=8):

    tokenizer = AutoTokenizer.from_pretrained(config.model_name)
    tokenizer.pad_token = tokenizer.eos_token
    # load imdb with datasets
    ds = load_dataset("yankihue/tweets-turkish", column_names=['Paylaşım','Tip'], split="train")
    ds = ds.rename_columns({"Paylaşım": "tweet", "Tip": "sentiment"})


    ds = ds.filter(lambda x: len(x["tweet"]) > 30, batched=False)
    input_size = LengthSampler(input_min_text_length, input_max_text_length)
    def tokenize(sample):
        sample["input_ids"] = tokenizer.encode(sample["tweet"])[: input_size()]
        sample["query"] = tokenizer.decode(sample["input_ids"])
        return sample

    ds = ds.map(tokenize, batched=False)
    ds.set_format(type="torch")
    return ds

# %%
dataset = build_dataset(config)

def collator(data):
    return dict((key, [d[key] for d in data]) for key in data[0])
# Out:
# tokenizer_config.json:   0%|          | 0.00/595 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/720 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/594k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/357 [00:00<?, ?B/s]
# Downloading data:   0%|          | 0.00/1.06M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Filter:   0%|          | 0/11108 [00:00<?, ? examples/s]
# Map:   0%|          | 0/9057 [00:00<?, ? examples/s]

# %%
dataset
# Out:
# Dataset({
#     features: ['tweet', 'sentiment', 'input_ids', 'query'],
#     num_rows: 9057
# })

# %%
dataset = dataset.select(range(5000))
dataset.num_rows
# Out:
# 5000

# %%
model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
ref_model = AutoModelForCausalLMWithValueHead.from_pretrained(config.model_name)
tokenizer = AutoTokenizer.from_pretrained(config.model_name)

tokenizer.eos_token_id = model.config.eos_token_id
tokenizer.pad_token = tokenizer.eos_token
# Out:
# pytorch_model.bin:   0%|          | 0.00/510M [00:00<?, ?B/s]

# %%
parametre_sayisi = sum(p.numel() for p in model.parameters())
print(f"GPT2 modelinin parametre sayısı: {parametre_sayisi}")
# Out:
# GPT2 modelinin parametre sayısı: 124440577

# %%
ppo_trainer = PPOTrainer(config, model, ref_model, tokenizer, dataset=dataset, data_collator=collator)
# Out:
# Finishing last run (ID:3bmmo6ku) before initializing another...
# VBox(children=(Label(value='0.002 MB of 0.002 MB uploaded\r'), FloatProgress(value=1.0, max=1.0)))
#  View run <strong style="color:#cdcd00">glowing-lion-21</strong> at: <a href='https://wandb.ai/ytu-bitirme-projesi/uncategorized/runs/3bmmo6ku' target="_blank">https://wandb.ai/ytu-bitirme-projesi/uncategorized/runs/3bmmo6ku</a><br/>Synced 4 W&B file(s), 0 media file(s), 0 artifact file(s) and 0 other file(s)
# Find logs at: <code>./wandb/run-20240101_102028-3bmmo6ku/logs</code>
# Successfully finished last run (ID:3bmmo6ku). Initializing new run:<br/>
# Tracking run with wandb version 0.16.1
# Run data is saved locally in <code>/content/wandb/run-20240101_102050-wcexw78v</code>
# Syncing run <strong><a href='https://wandb.ai/ytu-bitirme-projesi/trl/runs/wcexw78v' target="_blank">olive-firebrand-17</a></strong> to <a href='https://wandb.ai/ytu-bitirme-projesi/trl' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/run' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/ytu-bitirme-projesi/trl' target="_blank">https://wandb.ai/ytu-bitirme-projesi/trl</a>
#  View run at <a href='https://wandb.ai/ytu-bitirme-projesi/trl/runs/wcexw78v' target="_blank">https://wandb.ai/ytu-bitirme-projesi/trl/runs/wcexw78v</a>

# %%
device = ppo_trainer.accelerator.device
if ppo_trainer.accelerator.num_processes == 1:
    device = 0 if torch.cuda.is_available() else "cpu"  # to avoid a `pipeline` bug
sentiment_pipe = pipeline("sentiment-analysis", "savasy/bert-base-turkish-sentiment-cased", device=device)
# Out:
# config.json:   0%|          | 0.00/596 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/442M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/39.0 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/263k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]

# %%
text = "rezalet bir olay gerçekten ne diyeceğimi bilemiyorum"
sentiment_pipe(text, **sent_kwargs)
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# [[{'label': 'negative', 'score': 3.1516220569610596},
#   {'label': 'positive', 'score': -3.5145609378814697}]]

# %%
text = "harikasın ya iyi ki varsın abi gerçekten"
sentiment_pipe(text, **sent_kwargs)
# Out:
# [[{'label': 'negative', 'score': -2.506866693496704},
#   {'label': 'positive', 'score': 2.9172959327697754}]]

# %%
gen_kwargs = {"min_length": -1, "top_k": 0.0, "top_p": 1.0, "do_sample": True, "pad_token_id": tokenizer.eos_token_id}

# %%
output_min_length = 4
output_max_length = 16
output_length_sampler = LengthSampler(output_min_length, output_max_length)


generation_kwargs = {
    "min_length": -1,
    "top_k": 0.0,
    "top_p": 1.0,
    "do_sample": True,
    "pad_token_id": tokenizer.eos_token_id,
}


for epoch, batch in tqdm(enumerate(ppo_trainer.dataloader)):
    query_tensors = batch["input_ids"]

    #### Get response from gpt2
    response_tensors = []
    for query in query_tensors:
        gen_len = output_length_sampler()
        generation_kwargs["max_new_tokens"] = gen_len
        response = ppo_trainer.generate(query, **generation_kwargs)
        response_tensors.append(response.squeeze()[-gen_len:])
    batch["response"] = [tokenizer.decode(r.squeeze()) for r in response_tensors]

    """
    #### Compute sentiment score
    texts = [q + r for q, r in zip(batch["query"], batch["response"])]
    pipe_outputs = sentiment_pipe(texts, **sent_kwargs)
    rewards = [torch.tensor(output[1]["score"]) for output in pipe_outputs]

    #### Run PPO step
    stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
    ppo_trainer.log_stats(stats, batch, rewards)"""

    # Olumsuzluk skorlarını hesapla
    texts = [q + r for q, r in zip(batch["query"], batch["response"])]
    pipe_outputs = sentiment_pipe(texts, **sent_kwargs)
    # Skorları negatif olarak kullanarak ödül mekanizması oluştur
    rewards = [-1 * torch.tensor(output[1]["score"]) for output in pipe_outputs]
    # PPO Trainer'a ödül mekanizmasını dahil et
    stats = ppo_trainer.step(query_tensors, response_tensors, rewards)
    ppo_trainer.log_stats(stats, batch, rewards)
# Out:
# 0it [00:00, ?it/s]/usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (86.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (28.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (65.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (40.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (26.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (169.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (21.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (338.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (42.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (47.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (157.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (347.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (97.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (41.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (48.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (363.19) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (25.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (46.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (51.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (49.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (37.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (162.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (106.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 1it [02:01, 121.98s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (18.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (43.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (956.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (52.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (50.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (32.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (834.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (70.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (30.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (56.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (28.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (29.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (856.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (24.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (32.58) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (61.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (63.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (84.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (1728.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (42.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.35) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (41.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (64.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (32.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (920.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (55.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (66.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (87.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (1938.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (30.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (28.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (42.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (25.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (39.66) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 2it [04:02, 121.10s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (68.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (319.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (117.68) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (390.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (42.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (21.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (180.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (339.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (123.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (63.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (97.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (124.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (22.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (50.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (94.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (61.93) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (319.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (172.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.38) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (389.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (40.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.99) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (244.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (117.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (1087.17) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (37.43) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (51.86) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (61.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (97.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (256.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (125.11) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (178.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (319.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (389.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (116.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (1103.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 3it [06:04, 121.41s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (29.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (2784.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (275.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (76.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (42.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.07) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (28.03) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (327.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.92) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (28.02) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (28600.51) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (41.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (95.95) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (184.19) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (26.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (41.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (635.05) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (36.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (41.08) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (42.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (185.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (2780.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (28.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (353.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (376.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (35.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (22.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (624.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (36.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.18) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (26.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (26.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (76.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (97.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (30674.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.37) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (42.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (254.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.09) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (76.88) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (29583.89) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (359.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (43.44) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (26.81) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (199.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (24.42) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (101.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (37.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (45.25) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (2920.67) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (36.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (23.70) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (30.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (276.57) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (16.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (45.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (625.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (436.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 4it [08:04, 120.97s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (66.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (64.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (111.76) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (280.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (39.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (83.91) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (572.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (111.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (97.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (31.44) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (203.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (6004.96) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (306.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (2511.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (26.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (1071.16) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (240.74) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (80.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11718.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (435.41) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (46.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (299.44) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.59) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (47.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (171.27) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (77.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (29.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (2490.14) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# ...
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (24.30) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (26.53) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (91.29) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (113.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (159.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (47.09) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.71) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (38.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (86.04) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (56.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (50.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (212.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (77.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.77) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (24.61) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (39.75) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (25.90) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.36) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 18it [35:58, 118.95s/it]/usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.21) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (41.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (126.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (32.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (21.64) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (52.73) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (40.45) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (86.39) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (38.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (3102.26) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (105.82) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (42.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (21.34) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (456.40) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (36.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.06) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (457.10) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (2730.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (65.50) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.94) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (846.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (15.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (77.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (17.68) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (100.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (37.83) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.63) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (22.28) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (137.33) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.54) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (21.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.01) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (38.24) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (48.32) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (159.48) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (32.79) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (26.85) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (37.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (13.20) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (12.65) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (62.60) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.56) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (18.62) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (457.46) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (26.22) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (26.87) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (131.55) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (79.31) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.80) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (11.68) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (2583.12) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.78) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (48.52) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (102.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (45.69) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (10.13) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (151.00) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (850.23) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (14.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (18.15) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (19.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (33.97) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (20.84) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/trl/trainer/ppo_trainer.py:1205: UserWarning: The average ratio of batch (28.47) exceeds threshold 10.00. Skipping batch.
#   warnings.warn(
# 19it [37:56, 119.82s/it]

# %%
#### get a batch from the dataset / Negative rewarding model
bs = 16
game_data = dict()
dataset.set_format("pandas")
df_batch = dataset[:].sample(bs)
game_data["query"] = df_batch["query"].tolist()
query_tensors = df_batch["input_ids"].tolist()

response_tensors_ref, response_tensors = [], []

#### get response from gpt2 and gpt2_ref
for i in range(bs):
    gen_len = output_length_sampler()
    output = ref_model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors_ref.append(output)
    output = model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors.append(output)

#### decode responses
game_data["response (before)"] = [tokenizer.decode(response_tensors_ref[i]) for i in range(bs)]
game_data["response (after)"] = [tokenizer.decode(response_tensors[i]) for i in range(bs)]

#### sentiment analysis of query/response pairs before/after
texts = [q + r for q, r in zip(game_data["query"], game_data["response (before)"])]
game_data["rewards (before)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

texts = [q + r for q, r in zip(game_data["query"], game_data["response (after)"])]
game_data["rewards (after)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

# store results in a dataframe
df_results = pd.DataFrame(game_data)
df_results
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                         query  \
# 0               Şu hayatta sevmediğim bir kaç
# 1                   ders çalışmam lazım başım
# 2   Ülkenin her tarafında topraklar işleniyor
# 3                                 angut diyen
# 4       esra hanım teşekkürler evindeki güzel
# 5                                 Kırklareli
# 6          Hiç birimiz aptal yada saf değiliz
# 7        sana da cevap yazıyoruz ilgilenmiyor
# 8              bazen survivorı izlemeyi bırak
# 9                  bayadır tweet atmıyormuşum
# 10    diğer ailelerin hata olarak görüp sinir
# 11        Benim ne yapacağım, başkalarının ne
# 12                                   gözümüzü
# 13               bence dizi yapımları türkiye
# 14                                 4 gün önce
# 15                     Aptal ben chpliyim ama
#
#                                     response (before)  \
# 0    şeyi sevmeyebilirken bunu annen istemem; ben ...
# 1    da bilmek lazım ki söyliyonuz” dedi.\nBelediy...
# 2   . Askerler nasıl yüksek saflarda mücadele ediy...
# 3    pekçok kadın, bu kitap grubundaki genç meslek...
# 4   lerimizle başa çıkmaya çalışırken tam anlamıyl...
# 5                   de yeniden canlandırıldı.\nMartin
# 6   ... Artık bir fikrimiz var: fikir sahibi olmal...
# 7   sunuz diye.\nbu arada, cok cok etrafta olan in...
# 8   madılar. Şimdi sizin ve takımınızla ilgili yor...
# 9    bu kaymakamı...Bende cumhurbaşkanı olduğumda ...
# 10  leri aşırı derecede büyümek istedikleri lisans...
# 11   yapacağım, hangi yaptığımı sen bilirsin diyor...
# 12   dövün, gözlerimizi korkumuz bakmaya başlayalı...
# 13                     de sunulmaktadır.Haber siteniz
# 14                   acxsword'u gördüm.perien şarkı ö
# 15   chp nin logosu falan bu adam devlet tarafında...
#
#                                      response (after)  rewards (before)  \
# 0    kilo çok konuda pek yanlış, Odalar küçük ve s...          0.169426
# 1    aslında 3 soru zenginliğini de yaşlı varken ç...          0.723242
# 2   . Ancak biz bu, basit ve verimli kararların da...         -0.040652
# 3    ama kültür sadece anlamını, biricik beraberli...         -0.890498
# 4               birşeyleri yok, sizin yetersiz gelmes         -0.889617
# 5             nın tescilli bulunan bir akvaryum. Bu 5         -0.789945
# 6   . Yoksa sizi Neden iktidar edenler ( Bunlar da...          1.655492
# 7   , biraz zaman da zor değil, gereksiz, gereksiz...          0.079897
# 8                   başlı, iken daha bir cm az, hatta          1.682039
# 9    aptal yazana güzel bu da şuna bir hatadan dir...          2.037101
# 10   etmek için bunların neyi daha fazla araştırma...         -3.279047
# 11   istediğiniz kanunlarda takmamak üzerine çoğu ...         -2.973956
# 12  , biz çok asker ise diye zor ve zor ile bu sor...         -2.892906
# 13                       hakkında yürütülen m. Meselâ         -1.574207
# 14   az ve ortalama bir bu. ancak hiç bir zaman bi...          1.211450
# 15   geçen seçimlerde akp biz daha etkileyici bi d...         -2.807207
#
#     rewards (after)
# 0         -3.767405
# 1         -3.355452
# 2         -3.144861
# 3         -3.091585
# 4         -1.970495
# 5          0.465162
# 6         -1.891157
# 7         -4.277675
# 8         -2.829717
# 9         -1.139123
# 10        -3.660286
# 11        -2.733132
# 12        -3.217825
# 13        -2.461282
# 14        -2.894248
# 15        -2.962502

# %%
#### get a batch from the dataset / Positive rewarding model
bs = 16
game_data = dict()
dataset.set_format("pandas")
df_batch = dataset[:].sample(bs)
game_data["query"] = df_batch["query"].tolist()
query_tensors = df_batch["input_ids"].tolist()

response_tensors_ref, response_tensors = [], []

#### get response from gpt2 and gpt2_ref
for i in range(bs):
    gen_len = output_length_sampler()
    output = ref_model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors_ref.append(output)
    output = model.generate(
        torch.tensor(query_tensors[i]).unsqueeze(dim=0).to(device), max_new_tokens=gen_len, **gen_kwargs
    ).squeeze()[-gen_len:]
    response_tensors.append(output)

#### decode responses
game_data["response (before)"] = [tokenizer.decode(response_tensors_ref[i]) for i in range(bs)]
game_data["response (after)"] = [tokenizer.decode(response_tensors[i]) for i in range(bs)]

#### sentiment analysis of query/response pairs before/after
texts = [q + r for q, r in zip(game_data["query"], game_data["response (before)"])]
game_data["rewards (before)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

texts = [q + r for q, r in zip(game_data["query"], game_data["response (after)"])]
game_data["rewards (after)"] = [output[1]["score"] for output in sentiment_pipe(texts, **sent_kwargs)]

# store results in a dataframe
df_results = pd.DataFrame(game_data)
df_results
# Out:
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/text_classification.py:105: UserWarning: `return_all_scores` is now deprecated,  if want a similar functionality use `top_k=None` instead of `return_all_scores=True` or `top_k=1` instead of `return_all_scores=False`.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/transformers/pipelines/base.py:1101: UserWarning: You seem to be using the pipelines sequentially on GPU. In order to maximize efficiency please use a dataset
#   warnings.warn(
#                                    query  \
# 0                   sortaç danla ya bana
# 1                        çikolata yiyemi
# 2                         bunların allah
# 3                  allahın cezası şirket
# 4       Artık bu siyasetenizden vazgeçin
# 5     Benimkini hiç uyarmadan kapattılar
# 6                          inanılmaz iyi
# 7                aşağılık yaratık ağzına
# 8              bire zındık bire gafil ne
# 9   kırık koltuk bozuk emniyet kemeri ab
# 10                   orasını bilemiyorum
# 11                          o zaman niye
# 12                                YÖRSAN
# 13                            Slayers'ta
# 14                    soytarı bunu görse
# 15                       müzik dinlerken
#
#                                     response (before)  \
# 0                    hiç alpmassiri davrandim bu ayet
# 1                                    itarepmoderntır.
# 2                               u ve yardımcısı olsun
# 3   imizin kaç önyargılı olduğu için çok fena geliyor
# 4                             . Arzu ederseniz buraya
# 5             . Ama o ona yanaşmayı bile düşünmedi.\n
# 6    bir şey olmadan güzel rüya tabirlerinde hata ...
# 7           kadar sızıyordu. Boğulduğu anda soyu daha
# 8                                  denesin der ki biz
# 9          anoz topuk ayakkabı küpe3. BÖLÜMLER:13 Pat
# 10   ancak Sezen Aksu ile çokta barışık olmak gere...
# 11   gergin insanlar ciğerlerini yakmamak için ned...
# 12                      BULUNDU 10.10.2018\nKürdistan
# 13                       , "Kara Şövalye" hareketinin
# 14   vaz geçmeyeceğini göreceklerdir verilecekleri...
# 15   havada... Hatta hatırlayınca derinden kızarmı...
#
#                                      response (after)  rewards (before)  \
# 0          yardım etmişti :)\nBen de öyle ben de öyle         -1.338080
# 1                              çok iyi bir göz açacak         -2.235195
# 2                                         [/VI :) mut         -0.712448
# 3                     ile :)\nBu dizisel kurgunun alt         -2.392598
# 4                                       ! :) demiş ki         -2.579488
# 5         :)\nbu ara kitabın 2 grup çok güzel tema ve         -1.982029
# 6    oyunumuza devam etsin :) :)\n Alfa odalarında...         -2.748604
# 7    geliyor :)\nBu değerler donanımıyla, karıncal...         -2.175610
# 8                                        :)\n"Ne oldu         -3.059922
# 9          um! :)\n-Bunun dışında soz okunanı olmayan         -2.287943
# 10                          :)\n-Bu sabah 53 fetenler          1.049818
# 11         halen. :)\n"gerçekte puzzleyı ben böyle tw         -0.837362
# 12  !!! :) bende de ara :)\nni andır mektuplar say...          2.149426
# 13               iddialı oyuncular var :)\n :) İyi ma          0.711280
# 14          :) :)\nBu sırada Topuz yine aklıma geldi,         -2.505938
# 15   askersiz Design'da belki de anlatıyordu :) 1 ...         -0.917097
#
#     rewards (after)
# 0          4.880540
# 1          0.841917
# 2          2.849741
# 3          2.630316
# 4          4.307703
# 5          4.242820
# 6          4.353574
# 7          4.573279
# 8          4.477749
# 9          3.249496
# 10         4.859756
# 11         4.760004
# 12         4.855923
# 13         4.798265
# 14         4.844675
# 15         4.671087

# %%
df_results.to_csv()
# Out:
# ',query,response (before),response (after),rewards (before),rewards (after)\n0,Kızların, mevcut yerine harçlık yardımı koyabilir.," unutulmaz yorumu, muhteşem bir gösteri.\n",-2.5662853717803955,2.8276572227478027\n1,twitter bile 280 karakter," dinleyip izledi. Fakat, Mille", ile her daim birbirinin far oluyor.,-2.6564016342163086,-2.0029516220092773\n2,sinirlenince bile güzel,leşmek istemiyordu. Bir ara oyun oynuyordum. Ansızın bacaklarım başıma, tanımak için sizin için güzelliğiyle bir albümde. nasıl müthiş bir müzikal! Çok,-0.561077892780304,2.929518699645996\n3,yürüse bile," vakit geçirmek isterseniz,", herkes için birebir!,-2.456841230392456,2.3438663482666016\n4,Bukadar O, Tekrar Erkek Arkadaşları Hedef Göster, kadar mükemmelsiniz. ;) S,-3.6907341480255127,4.088912010192871\n5,\x91Artık yeter\x92 dedirtti!, Medine Belediyesi \'Yemek alımı çok fazla mesleki yeterlilik ve mesleki yeterlilik Fark,"\nİki örnekle, Türkiye Hükümetimize bir üst perde. Uzun",0.20289736986160278,-0.7687273025512695\n6,lan geriz,ekalı bozmadı hipnodu olduran hoy prosa.,".) Bu unutulmaz günleri anlatıyor.\n“Hayat boyunca her değişik duyguyu, en",-3.1750168800354004,3.067518472671509\n7,hepinizin bildiği," bir masal gibi. geçtiğimiz günlerde, enzim sistemleri tanı", ve her kitabı büyük bir çalışmayla birlikte muhteşem konuklarınız,2.530687093734741,1.5266773700714111\n8,Sen hayatın boyunca 24 saat Amerik,anın yatıp nereye gün battığından,"ayı, çok seviyorum. Çok",-0.5847803950309753,2.7433691024780273\n9,seni sana anlatsam,.Açsa babam çıkmasın.Gayet hijyen aşkı had safh,......:)) �ler):)) İşte olur. Çok seri!,-0.5730347037315369,4.201298713684082\n10,Tablonun Bellini atöly,elerinde açıyoruz. Kütüphanemizde sergilediğimiz sanat eserleri sınıfının genç tasarımlarını sizler,emize ekledikleri Tech - Müzik- Sanat - Müzik- Müzik -,0.5927472114562988,3.043699264526367\n11,siz ne çirkin,tir. Onun için de tevbe ve istiğfar etmek lazım. Her," bir görüntü.\nBence ben genç olmanın en güzel derecesini ve güzelliğini",-0.7271475791931152,-0.8886516690254211\n12,çocuklarımız en, derinde zaman zaman çocuklarını, heyecanlı ve yaratıcı! Türkiye,0.3399180769920349,2.718519926071167\n13,bu yaz,iyi ogrenmek istiyorum ama burdugu ogrenimda anlama, her programda. diye :) herkesin güzelliğine sahip. Türkiye Bebek,-2.1107592582702637,4.761927604675293\n14,takip," sandalyeyi koyarak, her baş ve", herbükle. Şimdi o mükemmel,1.2060048580169678,3.19834041595459\n15,alın izleyin şunuda beyniniz, yaşlının çalışsın ağrısıyla dalga geçip abuk yarayı, bu kadar içten ve tutkulu… Dünyanın en büyük ödüllere sahip,-3.7893598079681396,3.1534202098846436\n'

# %%
print("mean:")
display(df_results[["rewards (before)", "rewards (after)"]].mean())
print()
print("median:")
display(df_results[["rewards (before)", "rewards (after)"]].median())
# Out:
# mean:
# rewards (before)   -0.740526
# rewards (after)     4.466399
# dtype: float64
# median:
# rewards (before)   -1.539353
# rewards (after)     4.789525
# dtype: float64

# %%
print("mean:")
display(df_results[["rewards (before)", "rewards (after)"]].mean())
print()
print("median:")
display(df_results[["rewards (before)", "rewards (after)"]].median())
# Out:
# mean:
# rewards (before)   -0.795061
# rewards (after)    -2.307837
# dtype: float64
# median:
# rewards (before)   -1.166735
# rewards (after)    -3.046183
# dtype: float64

# %%
from huggingface_hub import notebook_login, create_repo
notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
model.save_pretrained("final-gpt2-tr-positive-sentiment-tweets-final", push_to_hub=True)
tokenizer.save_pretrained("final-gpt2-tr-positive-sentiment-tweets-final", push_to_hub=True)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/_commit_api.py:232: UserWarning: About to update multiple times the same file in the same commit: 'pytorch_model.bin'. This can cause undesired inconsistencies in your repo.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/_commit_api.py:232: UserWarning: About to update multiple times the same file in the same commit: 'generation_config.json'. This can cause undesired inconsistencies in your repo.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/_commit_api.py:232: UserWarning: About to update multiple times the same file in the same commit: 'config.json'. This can cause undesired inconsistencies in your repo.
#   warnings.warn(
# Upload 2 LFS files:   0%|          | 0/2 [00:00<?, ?it/s]
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/498M [00:00<?, ?B/s]
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/_commit_api.py:232: UserWarning: About to update multiple times the same file in the same commit: 'special_tokens_map.json'. This can cause undesired inconsistencies in your repo.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/_commit_api.py:232: UserWarning: About to update multiple times the same file in the same commit: 'merges.txt'. This can cause undesired inconsistencies in your repo.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/_commit_api.py:232: UserWarning: About to update multiple times the same file in the same commit: 'tokenizer.json'. This can cause undesired inconsistencies in your repo.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/_commit_api.py:232: UserWarning: About to update multiple times the same file in the same commit: 'vocab.json'. This can cause undesired inconsistencies in your repo.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/_commit_api.py:232: UserWarning: About to update multiple times the same file in the same commit: 'added_tokens.json'. This can cause undesired inconsistencies in your repo.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/_commit_api.py:232: UserWarning: About to update multiple times the same file in the same commit: 'tokenizer_config.json'. This can cause undesired inconsistencies in your repo.
#   warnings.warn(
# ('final-gpt2-tr-positive-sentiment-tweets-final/tokenizer_config.json',
#  'final-gpt2-tr-positive-sentiment-tweets-final/special_tokens_map.json',
#  'final-gpt2-tr-positive-sentiment-tweets-final/vocab.json',
#  'final-gpt2-tr-positive-sentiment-tweets-final/merges.txt',
#  'final-gpt2-tr-positive-sentiment-tweets-final/added_tokens.json',
#  'final-gpt2-tr-positive-sentiment-tweets-final/tokenizer.json')
